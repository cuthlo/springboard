# %%
#Trial data loading and handling

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

def get_merged_csv(flist, **kwargs):
    return pd.concat([pd.read_csv(f, **kwargs) for f in flist], ignore_index=True)

path = '/Users/cuthlo/Documents/git/springboard/capstone_project1/data/'
fmask = os.path.join(path, 'On_Time_On_Time_Performance_*.csv')

data = get_merged_csv(glob.glob(fmask), index_col=None)

print(data.head(20))
print(data.tail(20))
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2862: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2862: DtypeWarning: Columns (48,69,76,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2862: DtypeWarning: Columns (48,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#     Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0   2016        4     10           3          1  2016-10-03            AA
# 1   2016        4     10           4          2  2016-10-04            AA
# 2   2016        4     10           1          6  2016-10-01            AA
# 3   2016        4     10           2          7  2016-10-02            AA
# 4   2016        4     10           3          1  2016-10-03            AA
# 5   2016        4     10           4          2  2016-10-04            AA
# 6   2016        4     10           5          3  2016-10-05            AA
# 7   2016        4     10           6          4  2016-10-06            AA
# 8   2016        4     10           7          5  2016-10-07            AA
# 9   2016        4     10           8          6  2016-10-08            AA
# 10  2016        4     10           9          7  2016-10-09            AA
# 11  2016        4     10          10          1  2016-10-10            AA
# 12  2016        4     10          11          2  2016-10-11            AA
# 13  2016        4     10          12          3  2016-10-12            AA
# 14  2016        4     10          13          4  2016-10-13            AA
# 15  2016        4     10          14          5  2016-10-14            AA
# 16  2016        4     10          15          6  2016-10-15            AA
# 17  2016        4     10          16          7  2016-10-16            AA
# 18  2016        4     10          17          1  2016-10-17            AA
# 19  2016        4     10          18          2  2016-10-18            AA
#
#     AirlineID Carrier TailNum      ...       Div4TailNum  Div5Airport  \
# 0       19805      AA  N786AA      ...               NaN          NaN
# 1       19805      AA  N794AA      ...               NaN          NaN
# 2       19805      AA  N783AA      ...               NaN          NaN
# 3       19805      AA  N798AA      ...               NaN          NaN
# 4       19805      AA  N786AA      ...               NaN          NaN
# 5       19805      AA  N794AA      ...               NaN          NaN
# 6       19805      AA  N797AA      ...               NaN          NaN
# 7       19805      AA  N785AA      ...               NaN          NaN
# 8       19805      AA  N786AA      ...               NaN          NaN
# 9       19805      AA  N790AA      ...               NaN          NaN
# 10      19805      AA  N784AA      ...               NaN          NaN
# 11      19805      AA  N794AA      ...               NaN          NaN
# 12      19805      AA  N786AA      ...               NaN          NaN
# 13      19805      AA  N786AA      ...               NaN          NaN
# 14      19805      AA  N790AA      ...               NaN          NaN
# 15      19805      AA  N797AA      ...               NaN          NaN
# 16      19805      AA  N787AA      ...               NaN          NaN
# 17      19805      AA  N783AA      ...               NaN          NaN
# 18      19805      AA  N796AA      ...               NaN          NaN
# 19      19805      AA  N788AA      ...               NaN          NaN
#
#     Div5AirportID  Div5AirportSeqID Div5WheelsOn Div5TotalGTime  \
# 0             NaN               NaN          NaN            NaN
# 1             NaN               NaN          NaN            NaN
# 2             NaN               NaN          NaN            NaN
# 3             NaN               NaN          NaN            NaN
# 4             NaN               NaN          NaN            NaN
# 5             NaN               NaN          NaN            NaN
# 6             NaN               NaN          NaN            NaN
# 7             NaN               NaN          NaN            NaN
# 8             NaN               NaN          NaN            NaN
# 9             NaN               NaN          NaN            NaN
# 10            NaN               NaN          NaN            NaN
# 11            NaN               NaN          NaN            NaN
# 12            NaN               NaN          NaN            NaN
# 13            NaN               NaN          NaN            NaN
# 14            NaN               NaN          NaN            NaN
# 15            NaN               NaN          NaN            NaN
# 16            NaN               NaN          NaN            NaN
# 17            NaN               NaN          NaN            NaN
# 18            NaN               NaN          NaN            NaN
# 19            NaN               NaN          NaN            NaN
#
#    Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 0               NaN            NaN         NaN           NaN
# 1               NaN            NaN         NaN           NaN
# 2               NaN            NaN         NaN           NaN
# 3               NaN            NaN         NaN           NaN
# 4               NaN            NaN         NaN           NaN
# 5               NaN            NaN         NaN           NaN
# 6               NaN            NaN         NaN           NaN
# 7               NaN            NaN         NaN           NaN
# 8               NaN            NaN         NaN           NaN
# 9               NaN            NaN         NaN           NaN
# 10              NaN            NaN         NaN           NaN
# 11              NaN            NaN         NaN           NaN
# 12              NaN            NaN         NaN           NaN
# 13              NaN            NaN         NaN           NaN
# 14              NaN            NaN         NaN           NaN
# 15              NaN            NaN         NaN           NaN
# 16              NaN            NaN         NaN           NaN
# 17              NaN            NaN         NaN           NaN
# 18              NaN            NaN         NaN           NaN
# 19              NaN            NaN         NaN           NaN
#
# [20 rows x 110 columns]
#          Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 5644997  2017        3      7           1          6  2017-07-01
# 5644998  2017        3      7           1          6  2017-07-01
# 5644999  2017        3      7           1          6  2017-07-01
# 5645000  2017        3      7           1          6  2017-07-01
# 5645001  2017        3      7           1          6  2017-07-01
# 5645002  2017        3      7           1          6  2017-07-01
# 5645003  2017        3      7           1          6  2017-07-01
# 5645004  2017        3      7           1          6  2017-07-01
# 5645005  2017        3      7           1          6  2017-07-01
# 5645006  2017        3      7           1          6  2017-07-01
# 5645007  2017        3      7           1          6  2017-07-01
# 5645008  2017        3      7           1          6  2017-07-01
# 5645009  2017        3      7           1          6  2017-07-01
# 5645010  2017        3      7           1          6  2017-07-01
# 5645011  2017        3      7           1          6  2017-07-01
# 5645012  2017        3      7           1          6  2017-07-01
# 5645013  2017        3      7           1          6  2017-07-01
# 5645014  2017        3      7           1          6  2017-07-01
# 5645015  2017        3      7           1          6  2017-07-01
# 5645016  2017        3      7           1          6  2017-07-01
#
#         UniqueCarrier  AirlineID Carrier TailNum      ...       Div4TailNum  \
# 5644997            WN      19393      WN  N724SW      ...               NaN
# 5644998            WN      19393      WN  N8656B      ...               NaN
# 5644999            WN      19393      WN  N8529Z      ...               NaN
# 5645000            WN      19393      WN  N565WN      ...               NaN
# 5645001            WN      19393      WN  N8509U      ...               NaN
# 5645002            WN      19393      WN  N8679A      ...               NaN
# 5645003            WN      19393      WN  N914WN      ...               NaN
# 5645004            WN      19393      WN  N762SW      ...               NaN
# 5645005            WN      19393      WN  N8531Q      ...               NaN
# 5645006            WN      19393      WN  N239WN      ...               NaN
# 5645007            WN      19393      WN  N8507C      ...               NaN
# 5645008            WN      19393      WN  N553WN      ...               NaN
# 5645009            WN      19393      WN  N7747C      ...               NaN
# 5645010            WN      19393      WN  N233LV      ...               NaN
# 5645011            WN      19393      WN  N7877H      ...               NaN
# 5645012            WN      19393      WN  N499WN      ...               NaN
# 5645013            WN      19393      WN  N8306H      ...               NaN
# 5645014            WN      19393      WN  N272WN      ...               NaN
# 5645015            WN      19393      WN  N947WN      ...               NaN
# 5645016            WN      19393      WN  N486WN      ...               NaN
#
#          Div5Airport  Div5AirportID  Div5AirportSeqID Div5WheelsOn  \
# 5644997          NaN            NaN               NaN          NaN
# 5644998          NaN            NaN               NaN          NaN
# 5644999          NaN            NaN               NaN          NaN
# 5645000          NaN            NaN               NaN          NaN
# 5645001          NaN            NaN               NaN          NaN
# 5645002          NaN            NaN               NaN          NaN
# 5645003          NaN            NaN               NaN          NaN
# 5645004          NaN            NaN               NaN          NaN
# 5645005          NaN            NaN               NaN          NaN
# 5645006          NaN            NaN               NaN          NaN
# 5645007          NaN            NaN               NaN          NaN
# 5645008          NaN            NaN               NaN          NaN
# 5645009          NaN            NaN               NaN          NaN
# 5645010          NaN            NaN               NaN          NaN
# 5645011          NaN            NaN               NaN          NaN
# 5645012          NaN            NaN               NaN          NaN
# 5645013          NaN            NaN               NaN          NaN
# 5645014          NaN            NaN               NaN          NaN
# 5645015          NaN            NaN               NaN          NaN
# 5645016          NaN            NaN               NaN          NaN
#
#         Div5TotalGTime Div5LongestGTime  Div5WheelsOff Div5TailNum  \
# 5644997            NaN              NaN            NaN         NaN
# 5644998            NaN              NaN            NaN         NaN
# 5644999            NaN              NaN            NaN         NaN
# 5645000            NaN              NaN            NaN         NaN
# 5645001            NaN              NaN            NaN         NaN
# 5645002            NaN              NaN            NaN         NaN
# 5645003            NaN              NaN            NaN         NaN
# 5645004            NaN              NaN            NaN         NaN
# 5645005            NaN              NaN            NaN         NaN
# 5645006            NaN              NaN            NaN         NaN
# 5645007            NaN              NaN            NaN         NaN
# 5645008            NaN              NaN            NaN         NaN
# 5645009            NaN              NaN            NaN         NaN
# 5645010            NaN              NaN            NaN         NaN
# 5645011            NaN              NaN            NaN         NaN
# 5645012            NaN              NaN            NaN         NaN
# 5645013            NaN              NaN            NaN         NaN
# 5645014            NaN              NaN            NaN         NaN
# 5645015            NaN              NaN            NaN         NaN
# 5645016            NaN              NaN            NaN         NaN
#
#          Unnamed: 109
# 5644997           NaN
# 5644998           NaN
# 5644999           NaN
# 5645000           NaN
# 5645001           NaN
# 5645002           NaN
# 5645003           NaN
# 5645004           NaN
# 5645005           NaN
# 5645006           NaN
# 5645007           NaN
# 5645008           NaN
# 5645009           NaN
# 5645010           NaN
# 5645011           NaN
# 5645012           NaN
# 5645013           NaN
# 5645014           NaN
# 5645015           NaN
# 5645016           NaN
#
# [20 rows x 110 columns]

# %%
data.describe()
# Out:
#                Year       Quarter         Month    DayofMonth     DayOfWeek  \
# count  5.645017e+06  5.645017e+06  5.645017e+06  5.645017e+06  5.645017e+06
# mean   2.016586e+03  2.510572e+00  6.531478e+00  1.577389e+01  3.919806e+00
# std    4.925702e-01  1.103813e+00  3.393505e+00  8.777610e+00  1.991641e+00
# min    2.016000e+03  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    2.016000e+03  2.000000e+00  4.000000e+00  8.000000e+00  2.000000e+00
# 50%    2.017000e+03  3.000000e+00  7.000000e+00  1.600000e+01  4.000000e+00
# 75%    2.017000e+03  3.000000e+00  9.000000e+00  2.300000e+01  6.000000e+00
# max    2.017000e+03  4.000000e+00  1.200000e+01  3.100000e+01  7.000000e+00
#
#           AirlineID     FlightNum  OriginAirportID  OriginAirportSeqID  \
# count  5.645017e+06  5.645017e+06     5.645017e+06        5.645017e+06
# mean   1.990043e+04  2.093448e+03     1.269180e+04        1.269183e+06
# std    3.808453e+02  1.704029e+03     1.534553e+03        1.534550e+05
# min    1.939300e+04  1.000000e+00     1.013500e+04        1.013503e+06
# 25%    1.979000e+04  7.110000e+02     1.129200e+04        1.129202e+06
# 50%    1.980500e+04  1.654000e+03     1.289200e+04        1.289204e+06
# 75%    2.030400e+04  2.963000e+03     1.405700e+04        1.405702e+06
# max    2.117100e+04  8.402000e+03     1.621800e+04        1.621801e+06
#
#        OriginCityMarketID      ...       Div4TailNum  Div5Airport  \
# count        5.645017e+06      ...               0.0          0.0
# mean         3.172580e+04      ...               NaN          NaN
# std          1.280902e+03      ...               NaN          NaN
# min          3.007000e+04      ...               NaN          NaN
# 25%          3.064700e+04      ...               NaN          NaN
# 50%          3.145300e+04      ...               NaN          NaN
# 75%          3.246700e+04      ...               NaN          NaN
# max          3.599100e+04      ...               NaN          NaN
#
#        Div5AirportID  Div5AirportSeqID  Div5WheelsOn  Div5TotalGTime  \
# count            0.0               0.0           0.0             0.0
# mean             NaN               NaN           NaN             NaN
# std              NaN               NaN           NaN             NaN
# min              NaN               NaN           NaN             NaN
# 25%              NaN               NaN           NaN             NaN
# 50%              NaN               NaN           NaN             NaN
# 75%              NaN               NaN           NaN             NaN
# max              NaN               NaN           NaN             NaN
#
#        Div5LongestGTime  Div5WheelsOff  Div5TailNum  Unnamed: 109
# count               0.0            0.0          0.0           0.0
# mean                NaN            NaN          NaN           NaN
# std                 NaN            NaN          NaN           NaN
# min                 NaN            NaN          NaN           NaN
# 25%                 NaN            NaN          NaN           NaN
# 50%                 NaN            NaN          NaN           NaN
# 75%                 NaN            NaN          NaN           NaN
# max                 NaN            NaN          NaN           NaN
#
# [8 rows x 91 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5645017 entries, 0 to 5645016
# Columns: 110 entries, Year to Unnamed: 109
# dtypes: float64(71), int64(20), object(19)
# memory usage: 4.6+ GB

# %%
data.shape
# Out:
# (5645017, 110)

# %%
table = pd.pivot_table(data, values=['CarrierDelay','WeatherDelay','NASDelay','SecurityDelay','LateAircraftDelay'], index=['Year','Month'], aggfunc=np.mean)
print(table)
# Out:
#             CarrierDelay  LateAircraftDelay   NASDelay  SecurityDelay  \
# Year Month
# 2016 8         22.618946          26.612274  15.832075       0.140455
#      9         19.192193          20.909148  15.137974       0.065085
#      10        18.915913          20.431968  14.930046       0.054041
#      11        19.130455          20.751117  13.801158       0.091658
#      12        20.540181          26.373143  13.821581       0.077843
# 2017 1         20.308836          24.947492  15.742495       0.079745
#      2         18.930677          22.681019  15.938597       0.042886
#      3         19.137921          24.301620  15.643426       0.052980
#      4         21.718166          28.001281  17.804847       0.048794
#      5         18.641663          24.829686  18.350145       0.050548
#      6         19.536186          27.944499  16.792375       0.086390
#      7         20.018559          27.856715  16.498824       0.088562
#
#             WeatherDelay
# Year Month
# 2016 8          2.690972
#      9          2.280297
#      10         1.025177
#      11         1.775034
#      12         3.235093
# 2017 1          3.368857
#      2          2.577602
#      3          2.094339
#      4          3.968039
#      5          1.641756
#      6          2.887689
#      7          3.251369

# %%
plt.figure()
table.plot()
plt.show()

# %%
data.shape
# Out:
# (5645017, 110)

# %%
df_trim[df_trim[['CarrierDelay']].isnull()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-262e79431ded> in <module>()
# ----> 1 df_trim[df_trim[['CarrierDelay']].isnull()]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
# -> 1960             return self._getitem_frame(key)
#    1961         elif is_mi_columns:
#    1962             return self._getitem_multilevel(key)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_frame(self, key)
#    2034         if key.values.size and not is_bool_dtype(key.values):
#    2035             raise ValueError('Must pass DataFrame with boolean values only')
# -> 2036         return self.where(key)
#    2037
#    2038     def query(self, expr, inplace=False, **kwargs):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in where(self, cond, other, inplace, axis, level, try_cast, raise_on_error)
#    5338         other = com._apply_if_callable(other, self)
#    5339         return self._where(cond, other, inplace, axis, level, try_cast,
# -> 5340                            raise_on_error)
#    5341
#    5342     @Appender(_shared_docs['where'] % dict(_shared_doc_kwargs, cond="False",
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _where(self, cond, other, inplace, axis, level, try_cast, raise_on_error)
#    5096             for dt in cond.dtypes:
#    5097                 if not is_bool_dtype(dt):
# -> 5098                     raise ValueError(msg.format(dtype=dt))
#    5099
#    5100         cond = cond.astype(bool, copy=False)
#
# ValueError: Boolean array expected for the condition, not float64

# %%
df_trim.columns
# Out:
# Index(['Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek', 'FlightDate',
#        'UniqueCarrier', 'AirlineID', 'Carrier', 'TailNum', 'FlightNum',
#        'OriginAirportID', 'OriginAirportSeqID', 'OriginCityMarketID', 'Origin',
#        'OriginCityName', 'OriginState', 'OriginStateFips', 'OriginStateName',
#        'OriginWac', 'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID',
#        'Dest', 'DestCityName', 'DestState', 'DestStateFips', 'DestStateName',
#        'DestWac', 'CRSDepTime', 'DepTime', 'DepDelay', 'DepDelayMinutes',
#        'DepDel15', 'DepartureDelayGroups', 'DepTimeBlk', 'TaxiOut',
#        'WheelsOff', 'WheelsOn', 'TaxiIn', 'CRSArrTime', 'ArrTime', 'ArrDelay',
#        'ArrDelayMinutes', 'ArrDel15', 'ArrivalDelayGroups', 'ArrTimeBlk',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CRSElapsedTime',
#        'ActualElapsedTime', 'AirTime', 'Flights', 'Distance', 'DistanceGroup',
#        'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay',
#        'LateAircraftDelay', 'FirstDepTime', 'TotalAddGTime'],
#       dtype='object')

# %%
df_trim.Carrier.value_counts(dropna=False)
# Out:
# WN    1318208
# DL     921318
# AA     899378
# OO     647559
# UA     569881
# EV     417624
# B6     293222
# AS     181115
# NK     149221
# F9      99320
# HA      78185
# VX      69986
# Name: Carrier, dtype: int64

# %%
df_trim.CarrierDelay.value_counts(dropna=False)
# Out:
# NaN        4591752
#  0.0        524861
#  1.0         21231
#  2.0         20677
#  3.0         20307
#  4.0         19747
#  6.0         19360
#  5.0         18671
#  7.0         17913
#  8.0         16586
#  9.0         15619
#  15.0        14471
#  10.0        14363
#  11.0        12992
#  16.0        12837
#  12.0        12123
#  17.0        11838
#  13.0        11248
#  18.0        10867
#  14.0        10650
#  19.0        10014
#  20.0         9449
#  21.0         8464
#  22.0         7808
#  23.0         7349
#  24.0         6883
#  25.0         6493
#  26.0         5996
#  27.0         5547
#  28.0         5265
#             ...
#  1261.0          1
#  1263.0          1
#  1266.0          1
#  1271.0          1
#  1212.0          1
#  1201.0          1
#  1139.0          1
#  1200.0          1
#  1144.0          1
#  1151.0          1
#  1152.0          1
#  1153.0          1
#  1157.0          1
#  1159.0          1
#  1160.0          1
#  1161.0          1
#  1163.0          1
#  1164.0          1
#  1167.0          1
#  1170.0          1
#  1171.0          1
#  1174.0          1
#  1178.0          1
#  1182.0          1
#  1183.0          1
#  1187.0          1
#  1190.0          1
#  1191.0          1
#  1195.0          1
#  2142.0          1
# Name: CarrierDelay, Length: 1302, dtype: int64
