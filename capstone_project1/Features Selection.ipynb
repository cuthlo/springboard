#
#    Carrier TailNum  FlightNum      ...        skyc1  skyc2  skyc3   skyc4  \
# 0       WN  N8607M       4197      ...          OVC      M      M       M
# 1       OO  N187PQ       4930      ...          CLR      M      M       M
# 2       OO  N187PQ       4931      ...          FEW      M      M       M
# 3       OO  N250SY       4938      ...          SCT    SCT      M       M
# 4       OO  N253SY       4940      ...          CLR      M      M       M
# 5       OO  N609SK       4941      ...          CLR      M      M       M
# 6       OO  N457SW       4946      ...          FEW    FEW      M       M
# 7       OO  N936SW       4959      ...          FEW    FEW      M       M
# 8       OO  N447SW       4960      ...          FEW    SCT      M       M
# 9       OO  N251SY       4965      ...          CLR      M      M       M
# 10      OO  N916EV       4972      ...          FEW    FEW      M       M
# 11      OO  N455CA       4929      ...          FEW    OVC      M       M
# 12      OO  N779CA       4974      ...          FEW    FEW      M       M
# 13      OO  N878AS       4978      ...          FEW    SCT    SCT     BKN
# 14      OO  N878AS       4978      ...          FEW    FEW    SCT     BKN
# 15      OO  N441SW       4980      ...          SCT    BKN      M       M
# 16      OO  N418SW       4981      ...          FEW    FEW    SCT     BKN
# 17      OO  N418SW       4981      ...          FEW    FEW    SCT     BKN
# 18      OO  N800SK       4999      ...          FEW    SCT      M       M
# 19      OO  N970SW       5002      ...          FEW      M      M       M
# 20      OO  N929EV       5003      ...          FEW    FEW      M       M
# 21      OO  N973SW       5007      ...          FEW    SCT    BKN       M
# 22      OO  N927SW       5008      ...          FEW    FEW    FEW       M
# 23      OO  N471CA       5011      ...          FEW    SCT    BKN       M
# 24      OO  N917SW       5012      ...          BKN    BKN      M       M
# 25      OO  N463SW       4977      ...          FEW    FEW      M       M
# 26      OO  N471CA       5013      ...          FEW    FEW      M       M
# 27      OO  N461SW       4927      ...          FEW    OVC      M       M
# 28      OO  N247SY       4910      ...          CLR      M      M       M
# 29      OO  N813SK       4853      ...          FEW    SCT    SCT       M
# ..     ...     ...        ...      ...          ...    ...    ...     ...
# 70      OO  N975SW       5136      ...          BKN    BKN      M       M
# 71      OO  N932EV       5091      ...          FEW      M      M       M
# 72      OO  N925SW       5137      ...          FEW    FEW      M       M
# 73      OO  N938SW       5143      ...          FEW    FEW      M       M
# 74      OO  N979SW       5150      ...          FEW      M      M       M
# 75      OO  N963SW       5160      ...          FEW      M      M       M
# 76      OO  N961SW       5166      ...          FEW    OVC      M       M
# 77      OO  N961SW       5166      ...          FEW    OVC      M       M
# 78      OO  N912SW       5168      ...          BKN      M      M       M
# 79      OO  N794SK       5177      ...          FEW      M      M       M
# 80      OO  N786SK       5178      ...          FEW      M      M       M
# 81      OO  N952SW       5179      ...          FEW      M      M       M
# 82      OO  N908SW       5180      ...          FEW      M      M       M
# 83      OO  N923SW       5183      ...          FEW    SCT    BKN       M
# 84      OO  N943SW       5141      ...          FEW    FEW      M       M
# 85      OO  N937SW       5087      ...          FEW      M      M       M
# 86      OO  N962SW       5084      ...          BKN    OVC      M       M
# 87      OO  N934SW       5075      ...          FEW    FEW    FEW       M
# 88      OO  N472CA       5019      ...          SCT    BKN      M       M
# 89      OO  N924SW       5021      ...          OVC      M      M       M
# 90      OO  N976SW       5023      ...          BKN    BKN      M       M
# 91      OO  N939SW       5025      ...          FEW    OVC      M       M
# 92      OO  N939SW       5025      ...          FEW    OVC      M       M
# 93      OO  N963SW       5027      ...          FEW      M      M       M
# 94      OO  N939SW       5029      ...          FEW    BKN    OVC       M
# 95      OO  N917SW       5030      ...          FEW    FEW    FEW       M
# 96      OO  N956SW       5032      ...          FEW    FEW      M       M
# 97      OO  N976SW       5038      ...          OVC      M      M       M
# 98      OO  N976SW       5039      ...          BKN    BKN      M       M
# 99      OO  N976SW       5039      ...          SCT    BKN      M       M
#
#        skyl1     skyl2     skyl3     skyl4   presentwx         DateHr
# 0     400.00         M         M         M           M  2017-07-01 10
# 1          M         M         M         M           M  2017-07-01 20
# 2   20000.00         M         M         M           M  2017-07-02 00
# 3    1900.00   2500.00         M         M           M  2017-07-01 20
# 4          M         M         M         M           M  2017-07-02 01
# 5          M         M         M         M           M  2017-07-02 04
# 6   10000.00  22000.00         M         M           M  2017-07-01 21
# 7   11000.00  20000.00         M         M           M  2017-07-01 17
# 8   15000.00  25000.00         M         M           M  2017-07-01 14
# 9          M         M         M         M           M  2017-07-02 02
# 10   6000.00  20000.00         M         M           M  2017-07-02 00
# 11    800.00   2500.00         M         M           M  2017-07-01 12
# 12  10000.00  22000.00         M         M           M  2017-07-01 21
# 13   1800.00   3600.00   7500.00  20000.00       -TSRA  2017-07-02 00
# 14   3600.00   5000.00   9000.00  20000.00       -TSRA  2017-07-02 00
# 15   9000.00  25000.00         M         M           M  2017-07-01 16
# 16   3600.00   5500.00   8500.00  20000.00           M  2017-07-02 01
# 17   3400.00   5500.00   9000.00  20000.00          TS  2017-07-02 01
# 18   5000.00  25000.00         M         M           M  2017-07-01 20
# 19    700.00         M         M         M           M  2017-07-02 01
# 20   6000.00  15000.00         M         M           M  2017-07-02 00
# 21   6000.00  13000.00  25000.00         M           M  2017-07-01 12
# 22  10000.00  16000.00  22000.00         M           M  2017-07-02 01
# 23   6000.00  13000.00  25000.00         M           M  2017-07-01 12
# 24   5500.00   7000.00         M         M           M  2017-07-01 18
# 25   6000.00  20000.00         M         M           M  2017-07-02 00
# 26   5000.00  25000.00         M         M           M  2017-07-01 15
# 27    800.00   2500.00         M         M           M  2017-07-01 12
# 28         M         M         M         M           M  2017-07-01 22
# 29   2500.00  14000.00  25000.00         M           M  2017-07-01 21
# ..       ...       ...       ...       ...         ...            ...
# 70   5500.00   7000.00         M         M           M  2017-07-01 18
# 71    900.00         M         M         M           M  2017-07-01 20
# 72  10000.00  22000.00         M         M           M  2017-07-01 21
# 73   6000.00  15000.00         M         M           M  2017-07-02 00
# 74    900.00         M         M         M           M  2017-07-01 23
# 75    900.00         M         M         M           M  2017-07-01 21
# 76   1000.00   1500.00         M         M          BR  2017-07-01 18
# 77   1000.00   1500.00         M         M          HZ  2017-07-01 18
# 78   6000.00         M         M         M           M  2017-07-01 17
# 79  22000.00         M         M         M           M  2017-07-01 15
# 80  22000.00         M         M         M           M  2017-07-01 15
# 71  2017        3      7           1          6  2017-07-01      OO  N932EV
# 72  2017        3      7           1          6  2017-07-01      OO  N925SW
# 73  2017        3      7           1          6  2017-07-01      OO  N938SW
# 74  2017        3      7           1          6  2017-07-01      OO  N979SW
# 75  2017        3      7           1          6  2017-07-01      OO  N963SW
# 76  2017        3      7           1          6  2017-07-01      OO  N961SW
# 77  2017        3      7           1          6  2017-07-01      OO  N961SW
# 78  2017        3      7           1          6  2017-07-01      OO  N912SW
# 79  2017        3      7           1          6  2017-07-01      OO  N794SK
# 80  2017        3      7           1          6  2017-07-01      OO  N786SK
# 81  2017        3      7           1          6  2017-07-01      OO  N952SW
# 82  2017        3      7           1          6  2017-07-01      OO  N908SW
# 83  2017        3      7           1          6  2017-07-01      OO  N923SW
# 84  2017        3      7           1          6  2017-07-01      OO  N943SW
# 85  2017        3      7           1          6  2017-07-01      OO  N937SW
# 86  2017        3      7           1          6  2017-07-01      OO  N962SW
# 87  2017        3      7           1          6  2017-07-01      OO  N934SW
# 88  2017        3      7           1          6  2017-07-01      OO  N472CA
# 89  2017        3      7           1          6  2017-07-01      OO  N924SW
# 90  2017        3      7           1          6  2017-07-01      OO  N976SW
# 91  2017        3      7           1          6  2017-07-01      OO  N939SW
# 92  2017        3      7           1          6  2017-07-01      OO  N939SW
# 93  2017        3      7           1          6  2017-07-01      OO  N963SW
# 94  2017        3      7           1          6  2017-07-01      OO  N939SW
# 95  2017        3      7           1          6  2017-07-01      OO  N917SW
# 96  2017        3      7           1          6  2017-07-01      OO  N956SW
# 97  2017        3      7           1          6  2017-07-01      OO  N976SW
# 98  2017        3      7           1          6  2017-07-01      OO  N976SW
# 99  2017        3      7           1          6  2017-07-01      OO  N976SW
#
#     FlightNum Origin      ...        skyc1  skyc2   skyc3  skyc4     skyl1  \
# 0        4197    ATL      ...          OVC      M       M      M    400.00
# 1        4930    LAS      ...          CLR      M       M      M         M
# 2        4931    LAS      ...          FEW      M       M      M  20000.00
# 3        4938    LAX      ...          SCT    SCT       M      M   1900.00
# 4        4940    SEA      ...          CLR      M       M      M         M
# 5        4941    SEA      ...          CLR      M       M      M         M
# 6        4946    SLC      ...          FEW    FEW       M      M  10000.00
# 7        4959    SLC      ...          FEW    FEW       M      M  11000.00
# 8        4960    MSP      ...          FEW    SCT       M      M  15000.00
# 9        4965    SEA      ...          CLR      M       M      M         M
# 10       4972    DTW      ...          FEW    FEW       M      M   6000.00
# 11       4929    DTW      ...          FEW    OVC       M      M    800.00
# 12       4974    SLC      ...          FEW    FEW       M      M  10000.00
# 13       4978    ATL      ...          FEW    SCT     SCT    BKN   1800.00
# 14       4978    ATL      ...          FEW    FEW     SCT    BKN   3600.00
# 15       4980    MSP      ...          SCT    BKN       M      M   9000.00
# 16       4981    ATL      ...          FEW    FEW     SCT    BKN   3600.00
# 17       4981    ATL      ...          FEW    FEW     SCT    BKN   3400.00
# 18       4999    MSP      ...          FEW    SCT       M      M   5000.00
# 19       5002    SFO      ...          FEW      M       M      M    700.00
# 20       5003    ORD      ...          FEW    FEW       M      M   6000.00
# 21       5007    ORD      ...          FEW    SCT     BKN      M   6000.00
# 22       5008    DEN      ...          FEW    FEW     FEW      M  10000.00
# 23       5011    ORD      ...          FEW    SCT     BKN      M   6000.00
# 24       5012    ORD      ...          BKN    BKN       M      M   5500.00
# 25       4977    DTW      ...          FEW    FEW       M      M   6000.00
# 26       5013    ORD      ...          FEW    FEW       M      M   5000.00
# 27       4927    DTW      ...          FEW    OVC       M      M    800.00
# 28       4910    SEA      ...          CLR      M       M      M         M
# 29       4853    DFW      ...          FEW    SCT     SCT      M   2500.00
# ..        ...    ...      ...          ...    ...     ...    ...       ...
# 70       5136    ORD      ...          BKN    BKN       M      M   5500.00
# 71       5091    SFO      ...          FEW      M       M      M    900.00
# 72       5137    DEN      ...          FEW    FEW       M      M  10000.00
# 73       5143    ORD      ...          FEW    FEW       M      M   6000.00
# 74       5150    SFO      ...          FEW      M       M      M    900.00
# 75       5160    SFO      ...          FEW      M       M      M    900.00
# 76       5166    LAX      ...          FEW    OVC       M      M   1000.00
# 77       5166    LAX      ...          FEW    OVC       M      M   1000.00
# 78       5168    ORD      ...          BKN      M       M      M   6000.00
# 79       5177    DEN      ...          FEW      M       M      M  22000.00
# 80       5178    DEN      ...          FEW      M       M      M  22000.00
# 81       5179    DEN      ...          FEW      M       M      M  22000.00
# 82       5180    DEN      ...          FEW      M       M      M  22000.00
# 83       5183    SLC      ...          FEW    SCT     BKN      M  14000.00
# 84       5141    ORD      ...          FEW    FEW       M      M   5000.00
# 85       5087    SFO      ...          FEW      M       M      M    600.00
# 86       5084    SFO      ...          BKN    OVC       M      M    700.00
# 87       5075    DEN      ...          FEW    FEW     FEW      M  10000.00
# 88       5019    LAX      ...          SCT    BKN       M      M   1600.00
# 89       5021    LAX      ...          OVC      M       M      M   1300.00
# 90       5023    LAX      ...          BKN    BKN       M      M   1100.00
# 91       5025    LAX      ...          FEW    OVC       M      M   1000.00
# 92       5025    LAX      ...          FEW    OVC       M      M   1000.00
# 93       5027    SFO      ...          FEW      M       M      M    500.00
# 94       5029    SFO      ...          FEW    BKN     OVC      M    600.00
# 95       5030    ORD      ...          FEW    FEW     FEW      M   4000.00
# 96       5032    DEN      ...          FEW    FEW       M      M   9000.00
# 97       5038    LAX      ...          OVC      M       M      M   1900.00
# 98       5039    LAX      ...          BKN    BKN       M      M   1400.00
# 99       5039    LAX      ...          SCT    BKN       M      M   1000.00
#
#        skyl2     skyl3     skyl4   presentwx         DateHr
# 0          M         M         M           M  2017-07-01 10
# 1          M         M         M           M  2017-07-01 20
# 2          M         M         M           M  2017-07-02 00
# 3    2500.00         M         M           M  2017-07-01 20
# 4          M         M         M           M  2017-07-02 01
# 5          M         M         M           M  2017-07-02 04
# 6   22000.00         M         M           M  2017-07-01 21
# 7   20000.00         M         M           M  2017-07-01 17
# 8   25000.00         M         M           M  2017-07-01 14
# 9          M         M         M           M  2017-07-02 02
# 10  20000.00         M         M           M  2017-07-02 00
# 11   2500.00         M         M           M  2017-07-01 12
# 12  22000.00         M         M           M  2017-07-01 21
# 13   3600.00   7500.00  20000.00       -TSRA  2017-07-02 00
# 14   5000.00   9000.00  20000.00       -TSRA  2017-07-02 00
# 15  25000.00         M         M           M  2017-07-01 16
# 16   5500.00   8500.00  20000.00           M  2017-07-02 01
# 17   5500.00   9000.00  20000.00          TS  2017-07-02 01
# 18  25000.00         M         M           M  2017-07-01 20
# 19         M         M         M           M  2017-07-02 01
# 20  15000.00         M         M           M  2017-07-02 00
# 21  13000.00  25000.00         M           M  2017-07-01 12
# 22  16000.00  22000.00         M           M  2017-07-02 01
# 23  13000.00  25000.00         M           M  2017-07-01 12
# 24   7000.00         M         M           M  2017-07-01 18
# 25  20000.00         M         M           M  2017-07-02 00
# 26  25000.00         M         M           M  2017-07-01 15
# 27   2500.00         M         M           M  2017-07-01 12
# 28         M         M         M           M  2017-07-01 22
# 29  14000.00  25000.00         M           M  2017-07-01 21
# ..       ...       ...       ...         ...            ...
# 70   7000.00         M         M           M  2017-07-01 18
# 71         M         M         M           M  2017-07-01 20
# 72  22000.00         M         M           M  2017-07-01 21
# 73  15000.00         M         M           M  2017-07-02 00
# 74         M         M         M           M  2017-07-01 23
# 75         M         M         M           M  2017-07-01 21
# 76   1500.00         M         M          BR  2017-07-01 18
# 77   1500.00         M         M          HZ  2017-07-01 18
# 78         M         M         M           M  2017-07-01 17
# 79         M         M         M           M  2017-07-01 15
# 80         M         M         M           M  2017-07-01 15
# 81         M         M         M           M  2017-07-01 15
# 82         M         M         M           M  2017-07-01 15
# 83  17000.00  22000.00         M           M  2017-07-02 02
# 84  25000.00         M         M           M  2017-07-01 15
# 85         M         M         M           M  2017-07-02 02
# 86   1000.00         M         M           M  2017-07-01 13
# 87  16000.00  22000.00         M           M  2017-07-02 01
# 88   2300.00         M         M           M  2017-07-01 21
# 89         M         M         M           M  2017-07-02 04
# 90   1600.00         M         M           M  2017-07-02 01
# 91   1500.00         M         M          BR  2017-07-01 18
# 92   1500.00         M         M          HZ  2017-07-01 18
# 93         M         M         M           M  2017-07-02 05
# 94    800.00   1000.00         M           M  2017-07-01 14
# 95  12000.00  25000.00         M           M  2017-07-01 14
# 96  22000.00         M         M           M  2017-07-01 17
# 97         M         M         M           M  2017-07-01 19
# 98   1900.00         M         M           M  2017-07-01 22
# 99   1400.00         M         M           M  2017-07-01 22
#
# [100 rows x 71 columns]

# %%
df.columns.get_loc('IsDelay')
# Out:
# 43

# %%
# %%time

array = df.values
X = array[:,0:43]
Y = array[:,43]
# feature extraction
model = LogisticRegression()
rfe = RFE(model, 3)
fit = rfe.fit(X, Y)
print("Num Features: ", fit.n_features_)
print("Selected Features: ", fit.support_)
print("Feature Ranking: ",fit.ranking_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>()
#
# /anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/rfe.py in fit(self, X, y)
#     132             The target values.
#     133         """
# --> 134         return self._fit(X, y)
#     135
#     136     def _fit(self, X, y, step_score=None):
#
# /anaconda3/lib/python3.6/site-packages/sklearn/feature_selection/rfe.py in _fit(self, X, y, step_score)
#     140         # self.scores_ will not be calculated when calling _fit through fit
#     141
# --> 142         X, y = check_X_y(X, y, "csc")
#     143         # Initialization
#     144         n_features = X.shape[1]
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: '0900-0959'
